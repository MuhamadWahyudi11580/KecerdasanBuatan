# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamadWahyudi11580/KecerdasanBuatan/blob/main/Untitled47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import random


class Algoritma_genetika :


	jum_chrom = 6 
	gen = ["a", "b", "c", "d"] 
	nilai_per_gen = {
		'min' : 0,
		'max' : 10
	} 
    
	crossover_rate = 50/100 
	mutasi_rate = 10/100 
	total_gen = 24

	next_gen = np.arange(4)
	stop = False

 
  #inisialisasi kromosom secara random 
	def __init__(self):
		self.first_chrom = np.random.randint(low=self.nilai_per_gen['min'], high=self.nilai_per_gen['max'], size=(self.jum_chrom, len(self.gen)))
		print("==================================================inisialisasi=================================================")
		print(self.first_chrom)
		print("---------------------------------------------------------------------------------------------------------------")

#evaluasi
	def evaluasi_chrom(self, chrom, generasi):
		# mencari fungsi objektif
		# fungsi_objektif(chromosome) = | (a+2b+3c+4d) – 30 |
		print("GENERASI ["+str(generasi)+"] ------")
		
		jum_chromo = len(chrom)
		o = np.arange(jum_chromo)   
		fitness = np.arange(jum_chromo, dtype='f')
		
		for x in range(len(chrom)):
		
		
			fo = abs((chrom[x][0]+2*chrom[x][1]+3*chrom[x][2]+4*chrom[x][3])-30)
			o[x] = fo
			
		    #seleksi kromosom dan mencari fitness
			fitn = 1/(fo+1)
			
			fitness[x] = fitn
			if(fitn == 1):
				self.stop = True
			print("CHROMOSOME {0} : {1}, fitness = {2}".format(x, np.array2string(chrom[x], separator=','), fitn))
		print("FITNESS SELESAI!!")
		print(o)
		
        
     #probabilitas
		Probab = np.arange(jum_chromo, dtype='f')
	
		total_fitness = fitness.sum() 
		Probab = fitness / total_fitness 
		print("Total fitness : {}".format(str(total_fitness)))
		print("Rata-rata fitness : {}".format(str(np.average(fitness))))
		print("Probabilitas : {}".format(np.array2string(Probab, separator=',')))
		print("Probabilitas Paling Tinggi : {}, Pada chromosome ke {}".format(Probab[Probab.argmax()], str(Probab.argmax())))
		print("CHROMOSOME YANG MUNGKIN TERPILIH : {}".format(np.array2string(chrom[Probab.argmax()], separator=',')))
		print("")
		print("")
		self.next_gen = chrom[Probab.argmax()]

     #seleksi dengan menggunakan ROULETE WHELL
		C = np.arange(jum_chromo, dtype='f')
		total_x = 0
		for x in range(len(Probab)):
			total_x += Probab[x]
			C[x] = total_x

#putar roulete whell sebanyak 6 kali

		R = np.random.sample(len(fitness))
		chrom_baru = np.arange(jum_chromo*len(self.gen)).reshape(jum_chromo, len(self.gen))


#rumus mencari kromosom baru berdasarkan roulete whell

		for y in range(len(R)):
			for k in range(len(chrom_baru)):
				if(R[y] < C[0]):
					chrom_baru[y] = chrom[0]
				elif((C[k-1] < R[y]) & (R[y] < C[k])):
					chrom_baru[y] = chrom[k]

     #mencari crossover

		R = np.random.sample(jum_chromo)
		index_chrom_parent = [] # [1,2,3, ...]
		for p in range(len(R)):
			if(R[p] < self.crossover_rate):
				index_chrom_parent.append(p)

      #menentukan posisi crossover

		posisi_cros = np.random.randint(low=1, high=len(self.gen), size=len(index_chrom_parent))

    #menentukan posisi cut-point crossover

		offspring = np.arange(len(self.gen)*len(index_chrom_parent)).reshape(len(index_chrom_parent), len(self.gen))
		for i_parent in range(len(index_chrom_parent)):
			index_chrome_1 = index_chrom_parent[i_parent]
			if(i_parent == len(index_chrom_parent)-1):
				index_chrome_2 = index_chrom_parent[0]
			else:
				index_chrome_2 = index_chrom_parent[i_parent+1]

      #melakukan cut poin
		
			cut_point = posisi_cros[i_parent]
			for p in range(len(chrom_baru[index_chrome_1])):
			
				if(p >= posisi_cros[i_parent]):
			
					offspring[i_parent][p] = chrom_baru[index_chrome_2][p]
				else:
					offspring[i_parent][p] = chrom_baru[index_chrome_1][p]

	 # Penggabungan offspring dengan chrom_baru

		for x in range(len(offspring)):
			chrom_baru[index_chrom_parent[x]] = offspring[x]
            
 #mutasi kromosom

		total_gen = len(chrom) * len(chrom[0])
		jum_mutasi = self.mutasi_rate * total_gen 
		jum_mutasi = int(jum_mutasi)

		random_i_mutasi = np.random.randint(low=0, high=total_gen, size=jum_mutasi)

		for x in range(len(random_i_mutasi)):
			index_mutasi = random_i_mutasi[x]
			byk_kromosom = len(chrom)
			byk_gen = len(chrom[0])
			random_value = random.randint(self.nilai_per_gen['min'], self.nilai_per_gen['max'])
			if(index_mutasi <= byk_gen):
				
				chrom_baru[0][index_mutasi-1]
			else:
			
				posisi_y = index_mutasi/byk_gen
				posisi_y = int(posisi_y)
				posisi_x = index_mutasi % byk_gen
				chrom_baru[posisi_y][posisi_x] = random_value
		return chrom_baru

	def do_now(self):
		chromosome_current = self.first_chrom
		for generasi in range(0, self.total_gen):
			if(self.stop != True):
				chromosome_current = self.evaluasi_chrom(chromosome_current, generasi)
		print("----------------------------------------------------------------------")
		print("ALL DONE!")
		print("CHROMOSOME TERTINGGI DAN TERBAIK ADALAH")
		print(self.next_gen)

run = Algoritma_genetika()
run.do_now()
# Out:
# ==================================================inisialisasi=================================================
# [[3 4 4 6]
#  [3 4 8 6]
#  [4 9 4 4]
#  [7 4 5 7]
#  [3 3 2 1]
#  [1 4 8 8]]
# ---------------------------------------------------------------------------------------------------------------
# GENERASI [0] ------
# CHROMOSOME 0 : [3,4,4,6], fitness = 0.05555555555555555
# CHROMOSOME 1 : [3,4,8,6], fitness = 0.03333333333333333
# CHROMOSOME 2 : [4,9,4,4], fitness = 0.047619047619047616
# CHROMOSOME 3 : [7,4,5,7], fitness = 0.034482758620689655
# CHROMOSOME 4 : [3,3,2,1], fitness = 0.08333333333333333
# CHROMOSOME 5 : [1,4,8,8], fitness = 0.027777777777777776
# FITNESS SELESAI!!
# [17 29 20 28 11 35]
# Total fitness : 0.28210184
# Rata-rata fitness : 0.047016975
# Probabilitas : [0.1969344 ,0.11816064,0.16880092,0.12223514,0.2954016 ,0.0984672 ]
# Probabilitas Paling Tinggi : 0.29540160298347473, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,3,2,1]
#
#
# GENERASI [1] ------
# CHROMOSOME 0 : [3,4,8,6], fitness = 0.03333333333333333
# CHROMOSOME 1 : [3,4,8,1], fitness = 0.1
# CHROMOSOME 2 : [3,9,4,4], fitness = 0.05
# CHROMOSOME 3 : [3,4,4,6], fitness = 0.05555555555555555
# CHROMOSOME 4 : [4,9,4,1], fitness = 0.1111111111111111
# CHROMOSOME 5 : [3,4,4,0], fitness = 0.125
# FITNESS SELESAI!!
# [29  9 19 17  8  7]
# Total fitness : 0.475
# Rata-rata fitness : 0.079166666
# Probabilitas : [0.07017545,0.21052632,0.10526316,0.11695907,0.23391813,0.2631579 ]
# Probabilitas Paling Tinggi : 0.2631579041481018, Pada chromosome ke 5
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,4,4,0]
#
#
# GENERASI [2] ------
# CHROMOSOME 0 : [3,4,4,4], fitness = 0.1
# CHROMOSOME 1 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 2 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 3 : [3,3,8,6], fitness = 0.03571428571428571
# CHROMOSOME 4 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 5 : [3,4,2,1], fitness = 0.1
# FITNESS SELESAI!!
# [ 9  3  7 27  7  9]
# Total fitness : 0.7357143
# Rata-rata fitness : 0.122619055
# Probabilitas : [0.13592233,0.3398058 ,0.1699029 ,0.04854369,0.1699029 ,0.13592233]
# Probabilitas Paling Tinggi : 0.33980581164360046, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,9,4,0]
#
#
# GENERASI [3] ------
# CHROMOSOME 0 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 1 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 2 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 3 : [3,4,4,7], fitness = 0.045454545454545456
# CHROMOSOME 4 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 5 : [3,4,4,0], fitness = 0.125
# FITNESS SELESAI!!
# [ 3  7  3 21  7  7]
# Total fitness : 0.92045456
# Rata-rata fitness : 0.1534091
# Probabilitas : [0.27160493,0.13580246,0.27160493,0.04938272,0.13580246,0.13580246]
# Probabilitas Paling Tinggi : 0.2716049253940582, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,9,4,0]
#
#
# GENERASI [4] ------
# CHROMOSOME 0 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 1 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 2 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 3 : [3,4,4,1], fitness = 0.25
# CHROMOSOME 4 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 5 : [3,4,4,0], fitness = 0.125
# FITNESS SELESAI!!
# [3 3 7 3 7 7]
# Total fitness : 1.125
# Rata-rata fitness : 0.1875
# Probabilitas : [0.22222222,0.22222222,0.11111111,0.22222222,0.11111111,0.11111111]
# Probabilitas Paling Tinggi : 0.2222222238779068, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,9,4,0]
#
#
# GENERASI [5] ------
# CHROMOSOME 0 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 1 : [3,4,9,1], fitness = 0.07692307692307693
# CHROMOSOME 2 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 3 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 4 : [3,4,4,0], fitness = 0.125
# CHROMOSOME 5 : [3,9,4,0], fitness = 0.25
# FITNESS SELESAI!!
# [ 3 12  3  7  7  3]
# Total fitness : 1.0769231
# Rata-rata fitness : 0.17948718
# Probabilitas : [0.23214285,0.07142857,0.23214285,0.11607143,0.11607143,0.23214285]
# Probabilitas Paling Tinggi : 0.2321428507566452, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,9,4,0]
#
#
# GENERASI [6] ------
# CHROMOSOME 0 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 1 : [3,9,4,3], fitness = 0.0625
# CHROMOSOME 2 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 3 : [3,9,4,9], fitness = 0.025
# CHROMOSOME 4 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 5 : [3,9,4,0], fitness = 0.25
# FITNESS SELESAI!!
# [ 3 15  3 39  3  3]
# Total fitness : 1.0875
# Rata-rata fitness : 0.18124999
# Probabilitas : [0.22988506,0.05747126,0.22988506,0.02298851,0.22988506,0.22988506]
# Probabilitas Paling Tinggi : 0.2298850566148758, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,9,4,0]
#
#
# GENERASI [7] ------
# CHROMOSOME 0 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 1 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 2 : [9,9,4,0], fitness = 0.1
# CHROMOSOME 3 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 4 : [6,9,4,0], fitness = 0.14285714285714285
# CHROMOSOME 5 : [3,9,4,0], fitness = 0.25
# FITNESS SELESAI!!
# [3 3 9 3 6 3]
# Total fitness : 1.2428572
# Rata-rata fitness : 0.20714287
# Probabilitas : [0.20114942,0.20114942,0.08045977,0.20114942,0.11494253,0.20114942]
# Probabilitas Paling Tinggi : 0.20114941895008087, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,9,4,0]
#
#
# GENERASI [8] ------
# CHROMOSOME 0 : [6,9,4,0], fitness = 0.14285714285714285
# CHROMOSOME 1 : [3,3,4,0], fitness = 0.1
# CHROMOSOME 2 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 3 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 4 : [3,9,4,0], fitness = 0.25
# CHROMOSOME 5 : [0,9,4,0], fitness = 1.0
# FITNESS SELESAI!!
# [6 9 3 3 3 0]
# Total fitness : 1.9928572
# Rata-rata fitness : 0.33214286
# Probabilitas : [0.07168459,0.05017921,0.12544802,0.12544802,0.12544802,0.5017921 ]
# Probabilitas Paling Tinggi : 0.5017920732498169, Pada chromosome ke 5
# CHROMOSOME YANG MUNGKIN TERPILIH : [0,9,4,0]
#
#
# ----------------------------------------------------------------------
# ALL DONE!
# CHROMOSOME TERTINGGI DAN TERBAIK ADALAH
# [0 9 4 0]
